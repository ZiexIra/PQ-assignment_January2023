# %% [markdown]
# <a href="https://colab.research.google.com/github/ZiexIra/PQ-assignment_January2023/blob/main/Copy_of_Voltage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def graph1(data1, data2, xAxis, yAxis):
    fig1 = plt.figure(figsize=(8,4))
    ax1 = fig1.add_subplot(111)
    ax1.plot(data1, data2, label='')
    ax1.grid(True)
    ax1.set_xlabel(xAxis)
    ax1.set_ylabel(yAxis)
    fig1.tight_layout()
    plt.show()

# %%
    x = np.linspace(0, 2*3.1415, 100)
    y = np.sin(x)

# %%
    graph1(x, y, 'Time [s]', 'U [m/s]')

# %%
import pandas as pd

# %%
from google.colab import files

# %%
import io

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-096afb02-1440-4c05-bb73-2f6a49bbac45" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-096afb02-1440-4c05-bb73-2f6a49bbac45">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
var = pd.read_excel("Data Voltage_300123.xlsx")
print(var)
# Out:
#           Date              Time  Voltage L1N Avg  Voltage L2N Avg  \
# 0   2019-03-07  12:16:40 301msec           243.23           242.23
# 1   2019-03-07  12:26:40 301msec           243.48           242.41
# 2   2019-03-07  12:36:40 301msec           244.03           242.91
# 3   2019-03-07  12:46:40 301msec           244.07           243.02
# 4   2019-03-07  12:56:40 301msec           244.10           243.02
# ..         ...               ...              ...              ...
# 498 2019-03-10  23:16:40 301msec           253.28           252.30
# 499 2019-03-10  23:26:40 301msec           253.47           252.52
# 500 2019-03-10  23:36:40 301msec           253.44           252.47
# 501 2019-03-10  23:46:40 301msec           253.85           252.95
# 502 2019-03-10  23:56:40 301msec           254.11           253.20
#
#      Voltage L3N Avg
# 0             242.69
# 1             242.87
# 2             243.46
# 3             243.54
# 4             243.55
# ..               ...
# ...

# %%
import matplotlib.pyplot as plt

# %%
X = list(var['Time'])
L1N = list(var['Voltage L1N Avg'])
L2N = list(var['Voltage L2N Avg'])
L3N = list(var['Voltage L3N Avg'])

# %%
plt.figure(figsize=(10,10))
plt.style.use('seaborn')
plt.scatter(x,y,marker="*",s=100,edgecolors="black",c="yellow")
plt.title("Excel sheet to Scatter Plot")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-794aaca045ca> in <module>
#       1 plt.figure(figsize=(10,10))
#       2 plt.style.use('seaborn')
# ----> 3 plt.scatter(x,y,marker="*",s=100,edgecolors="black",c="yellow")
#       4 plt.title("Excel sheet to Scatter Plot")
#       5 plt.show()
#
# NameError: name 'x' is not defined

# %%
plt.figure(figsize=(10,10))
plt.style.use('seaborn')
plt.plot(X, L1N, linestyle='--', color= 'Red', label= 'L1N')
plt.plot(X, L2N, linestyle='--', color= 'Yellow', label= 'L2N')
plt.plot(X, L3N, linestyle='--', color= 'Blue', label= 'L3N')
plt.title("Excel sheet to Line Plot")
plt.show()
